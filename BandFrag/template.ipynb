# %%
from matplotlib import pyplot as plt

x = X_AXIS

y_pauli = Y_AXIS_PAULI
y_dispersion = Y_AXIS_DISPERSION
y_elstat = Y_AXIS_ELSTAT
y_orbital = Y_AXIS_ORBITAL
y_interaction = Y_AXIS_INTERACTION

plt.plot(x, y_pauli, label = "Pauli")
plt.plot(x, y_dispersion, label = "Dispersion")
plt.plot(x, y_elstat, label = "Electrostatic Interaction")
plt.plot(x, y_orbital, label = "Orbital Interaction")
plt.plot(x, y_interaction, label = "Interaction")

plt.legend()

plt.xlabel("LABEL_BONDS bond stretch Å")
plt.ylabel("$\mathregular{\mathit{ΔE}\ /\ kcal\  mol^{-1}}$")

plt.show()

# %%
from matplotlib import pyplot as plt

x = X_AXIS

y_fragment_1 = Y_AXIS_FRAGMENT_1
y_fragment_2 = Y_AXIS_FRAGMENT_2

plt.plot(x, y_fragment_1, label = "Fragment_1")
plt.plot(x, y_fragment_2, label = "Fragment_2")

plt.legend()

plt.xlabel("LABEL_BONDS bond stretch Å")
plt.ylabel("$\mathregular{\mathit{ΔE}\ /\ kcal\  mol^{-1}}$")

plt.show()

# %%
from matplotlib import pyplot as plt

x = X_AXIS

y_fragment_1 = Y_AXIS_FRAGMENT_1
y_fragment_2 = Y_AXIS_FRAGMENT_2
y_interaction = Y_AXIS_INTERACTION

y_fragment_full = [y_fragment_1[i] + y_fragment_2[i] for i in range(len(y_fragment_1))]
y_delta_energy = [y_fragment_full[i] + y_interaction[i] for i in range(len(y_fragment_1))]

plt.plot(x, y_fragment_full, label = "Strain")
plt.plot(x, y_interaction, label = "Interaction")
plt.plot(x, y_delta_energy, label = "Total")

plt.legend()

plt.xlabel("LABEL_BONDS bond stretch Å")
plt.ylabel("$\mathregular{\mathit{ΔE}\ /\ kcal\  mol^{-1}}$")

plt.show()

# %%
from matplotlib import pyplot as plt

x = X_AXIS

y_pauli = Y_AXIS_PAULI

plt.plot(x, y_pauli)

plt.title("Pauli")

plt.xlabel("LABEL_BONDS bond stretch Å")
plt.ylabel("$\mathregular{\mathit{ΔE}\ /\ kcal\  mol^{-1}}$")

plt.show()

# %%
from matplotlib import pyplot as plt

x = X_AXIS

y_dispersion = Y_AXIS_DISPERSION

plt.plot(x, y_dispersion)
plt.gca().invert_yaxis()

plt.title("Dispersion")

plt.xlabel("LABEL_BONDS bond stretch Å")
plt.ylabel("$\mathregular{\mathit{ΔE}\ /\ kcal\  mol^{-1}}$")

plt.show()

# %%
from matplotlib import pyplot as plt

x = X_AXIS

y_elstat = Y_AXIS_ELSTAT

plt.plot(x, y_elstat)
plt.gca().invert_yaxis()

plt.title("Electrostatic")

plt.xlabel("LABEL_BONDS bond stretch Å")
plt.ylabel("$\mathregular{\mathit{ΔE}\ /\ kcal\  mol^{-1}}$")

plt.show()

# %%
from matplotlib import pyplot as plt

x = X_AXIS

y_orbital = Y_AXIS_ORBITAL

plt.plot(x, y_orbital)
plt.gca().invert_yaxis()

plt.title("Orbital Interactions")

plt.xlabel("LABEL_BONDS bond stretch Å")
plt.ylabel("$\mathregular{\mathit{ΔE}\ /\ kcal\  mol^{-1}}$")

plt.show()

# %%
from matplotlib import pyplot as plt

x = X_AXIS

y_interaction = Y_AXIS_INTERACTION

plt.plot(x, y_interaction)
plt.gca().invert_yaxis()

plt.title("Interaction")

plt.xlabel("LABEL_BONDS bond stretch Å")
plt.ylabel("$\mathregular{\mathit{ΔE}\ /\ kcal\  mol^{-1}}$")

plt.show()
