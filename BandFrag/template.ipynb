# %%
from matplotlib import pyplot as plt

x = X_AXIS
y1 = Y_AXIS_PAULI
y2 = Y_AXIS_DISPERSION
y3 = Y_AXIS_ELSTAT
y4 = Y_AXIS_ORBITAL
y5 = Y_AXIS_INTERACTION

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.plot(x, y5)

plt.show()
